# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Input Image

# %%
img = cv2.imread('../data/image_2.jpg')

# %%
img.shape
# Out:
# (798, 1199, 3)

# %%
plt.figure(figsize=(10,12))
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # Color space changing

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)

# %%
plt.figure(figsize=(10,12))
plt.imshow(gray,cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10,12))
plt.imshow(hsv,cmap='hsv')
plt.show()

# %% [markdown]
# ## This is how you convert BGR to RGB image

# %% [markdown]
# ## Method 1

# %%
a = np.random.randn(4,4,3)
a
# Out:
# array([[[-0.50230043,  2.49747797, -0.4828674 ],
#         [ 1.57745056, -1.86154615,  0.64459932],
#         [ 0.76659195,  0.85528916,  3.23369945],
#         [ 2.40004613,  2.41299797, -1.62012009]],
#
#        [[-1.35900459, -0.91801919,  0.82454759],
#         [-0.1200326 ,  0.45120507,  0.31146914],
#         [ 0.59037597,  0.82894232, -3.14515468],
#         [-0.22987644, -0.47800389, -0.41454499]],
#
#        [[ 1.31934287,  0.91050918,  0.82721397],
#         [-1.38997542, -0.47130205, -0.21047463],
#         [ 0.90732173, -0.11345582, -1.00722139],
#         [ 0.60319218,  0.31262745, -0.69460686]],
#
#        [[-1.06940081,  1.84860581,  2.31912676],
#         [ 2.61154994, -0.91217025,  0.77652383],
#         [ 1.14963823,  1.36056829,  0.87613408],
#         [-0.14098909,  0.02095078, -0.21286245]]])

# %%
a[::-1]
# Out:
# array([[[-1.06940081,  1.84860581,  2.31912676],
#         [ 2.61154994, -0.91217025,  0.77652383],
#         [ 1.14963823,  1.36056829,  0.87613408],
#         [-0.14098909,  0.02095078, -0.21286245]],
#
#        [[ 1.31934287,  0.91050918,  0.82721397],
#         [-1.38997542, -0.47130205, -0.21047463],
#         [ 0.90732173, -0.11345582, -1.00722139],
#         [ 0.60319218,  0.31262745, -0.69460686]],
#
#        [[-1.35900459, -0.91801919,  0.82454759],
#         [-0.1200326 ,  0.45120507,  0.31146914],
#         [ 0.59037597,  0.82894232, -3.14515468],
#         [-0.22987644, -0.47800389, -0.41454499]],
#
#        [[-0.50230043,  2.49747797, -0.4828674 ],
#         [ 1.57745056, -1.86154615,  0.64459932],
#         [ 0.76659195,  0.85528916,  3.23369945],
#         [ 2.40004613,  2.41299797, -1.62012009]]])

# %% [markdown]
# ## Method 2

# %%
plt.figure()
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()
